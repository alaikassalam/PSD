# %%
! pip install jupyterlab streamlit librosa scikit-learn sounddevice numpy scipy
# Out:
# Requirement already satisfied: jupyterlab in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (4.4.6)
# Requirement already satisfied: streamlit in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (1.51.0)
# Requirement already satisfied: librosa in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (0.11.0)
# Requirement already satisfied: scikit-learn in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (1.7.2)
# Requirement already satisfied: sounddevice in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (2.2.6)
# Requirement already satisfied: scipy in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (1.15.3)
# Requirement already satisfied: async-lru>=1.0.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (6.30.1)
# Requirement already satisfied: jinja2>=3.0.3 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (2.2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (63.2.0)
# Requirement already satisfied: tomli>=1.2.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (2.2.1)
# Requirement already satisfied: tornado>=6.2.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: traitlets in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.10.0)
# Requirement already satisfied: certifi in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.25.1)
# Requirement already satisfied: requests>=2.31 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.5)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (6.33.0)
# Requirement already satisfied: pyarrow<22,>=7.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: narwhals>=1.14.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.5.0)
# Requirement already satisfied: colorama in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.5.0)
# Requirement already satisfied: audioread>=2.1.9 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (0.62.1)
# Requirement already satisfied: joblib>=1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: CFFI>=1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: pycparser in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from CFFI>=1.0->sounddevice) (2.23)
# Requirement already satisfied: comm>=0.1.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.0.0)
# Requirement already satisfied: jedi>=0.16 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.19.2)
# Requirement already satisfied: stack_data in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: wcwidth in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.27.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-core->jupyterlab) (4.5.0)
# Requirement already satisfied: pywin32>=300 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-core->jupyterlab) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from numba>=0.51.0->librosa) (0.45.1)
# Requirement already satisfied: six>=1.5 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.0)
# Requirement already satisfied: pure-eval in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install sounddevice numpy scipy
# Out:
# Requirement already satisfied: sounddevice in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (2.2.6)
# Requirement already satisfied: scipy in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (1.15.3)
# Requirement already satisfied: CFFI>=1.0 in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in d:\laragon\laragon\bin\python\python-3.10\lib\site-packages (from CFFI>=1.0->sounddevice) (2.23)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wav
import os
import time

# %%
# --- Konfigurasi ---
JUMLAH_SAMPEL = 100      # 100x rekaman per kata
DURASI_REKAMAN = 1.5    # Durasi rekaman dalam detik (sesuaikan jika perlu)
SAMPLE_RATE = 22050     # Standar untuk speech recognition
KATA_TARGET = ["buka", "tutup"]
FOLDER_DATA = "./dataset/data-hasil"
# --------------------

def rekam_audio(durasi, sr):
    """Merekam audio dari mikrofon default."""
    print("Merekam...")
    audio = sd.rec(int(durasi * sr), samplerate=sr, channels=1, dtype='float32')
    sd.wait()  # Menunggu rekaman selesai
    print("Rekaman selesai.")
    return audio

def simpan_audio(audio, filename, sr):
    """Menyimpan audio ke file WAV."""
    # Normalisasi audio untuk menghindari clipping (jika terlalu keras)
    audio = audio / np.max(np.abs(audio))
    # Konversi ke 16-bit integer (format WAV standar)
    audio_int16 = (audio * 32767).astype(np.int16)
    wav.write(filename, sr, audio_int16)
    print(f"File disimpan di: {filename}")

def main():
    print("--- Skrip Perekam Data Audio ---")
    print(f"Target: {JUMLAH_SAMPEL} sampel per kata.")
    print(f"Kata: {', '.join(KATA_TARGET)}")
    print("----------------------------------\n")

    # Membuat folder data utama jika belum ada
    if not os.path.exists(FOLDER_DATA):
        os.makedirs(FOLDER_DATA)

    for kata in KATA_TARGET:
        print(f"\n======= MULAI MEREKAM KATA: '{kata.upper()}' =======")
        
        # Membuat sub-folder untuk setiap kata
        folder_kata = os.path.join(FOLDER_DATA, kata)
        if not os.path.exists(folder_kata):
            os.makedirs(folder_kata)
        
        print(f"Data akan disimpan di folder: {folder_kata}")
        print("Tekan ENTER untuk memulai rekaman pertama...")
        input() # Menunggu kesiapan pengguna

        for i in range(JUMLAH_SAMPEL):
            print(f"\n--- Merekam sampel ke-{i+1}/{JUMLAH_SAMPEL} untuk '{kata.upper()}' ---")
            
            # Beri waktu pengguna untuk bersiap
            try:
                print("Bersiap dalam 3...")
                time.sleep(1)
                print("2...")
                time.sleep(1)
                print("1...")
                time.sleep(1)
                print("BICARA SEKARANG!")

                # 1. Rekam
                audio_rekaman = rekam_audio(DURASI_REKAMAN, SAMPLE_RATE)
                
                # 2. Simpan
                # Format nama file: buka_001.wav, buka_002.wav, ...
                nama_file = f"{kata}_{i+1:03d}.wav" 
                path_file_lengkap = os.path.join(folder_kata, nama_file)
                simpan_audio(audio_rekaman, path_file_lengkap, SAMPLE_RATE)

                # Jeda singkat antar rekaman
                time.sleep(0.5)

            except KeyboardInterrupt:
                print("\nProses dihentikan oleh pengguna.")
                return
            except Exception as e:
                print(f"Terjadi error: {e}")
                print("Mencoba lanjut ke sampel berikutnya...")
                continue
    
    print("\n\n======== PENGUMPULAN DATA SELESAI! ========")
    print(f"Semua data tersimpan di folder '{FOLDER_DATA}'.")

if __name__ == "__main__":
    main()
# Out:
# --- Skrip Perekam Data Audio ---
# Target: 100 sampel per kata.
# Kata: buka, tutup
# ----------------------------------
#
#
# ======= MULAI MEREKAM KATA: 'BUKA' =======
# Data akan disimpan di folder: ./dataset/data-hasil\buka
# Tekan ENTER untuk memulai rekaman pertama...
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[4], line 85
#      82     print(f"Semua data tersimpan di folder '{FOLDER_DATA}'.")
#      84 if __name__ == "__main__":
# ---> 85     main()
#
# Cell In[4], line 46, in main()
#      44 print(f"Data akan disimpan di folder: {folder_kata}")
#      45 print("Tekan ENTER untuk memulai rekaman pertama...")
# ---> 46 input() # Menunggu kesiapan pengguna
#      48 for i in range(JUMLAH_SAMPEL):
#      49     print(f"\n--- Merekam sampel ke-{i+1}/{JUMLAH_SAMPEL} untuk '{kata.upper()}' ---")
#
# File D:\Laragon\laragon\bin\python\python-3.10\lib\site-packages\ipykernel\kernelbase.py:1274, in Kernel.raw_input(self, prompt)
#    1272 if not self._allow_stdin:
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
# -> 1274     raise StdinNotImplementedError(msg)
#    1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
# !pip install librosa pandas numpy tqdm

# %%
import librosa
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# Tentukan path ke folder data Anda
PATH_DATA = "./dataset/data-hasil/"
LABELS = ["buka", "tutup"]
SAMPLE_RATE = 22050

# --- PENYESUAIAN ---
# Mengubah jumlah MFCC dari 13 menjadi 20
N_MFCC = 20 
# -------------------

# Siapkan list untuk menampung data
data_fitur = []
data_label = []

print(f"Memulai ekstraksi fitur MFCC (n_mfcc={N_MFCC})...")

# Looping untuk setiap label (buka, tutup)
for label in LABELS:
    folder_path = os.path.join(PATH_DATA, label)
    
    # Dapatkan semua nama file di dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]
    
    # Gunakan tqdm untuk melihat progress bar
    for file_name in tqdm(files, desc=f"Processing {label}"):
        try:
            file_path = os.path.join(folder_path, file_name)
            
            # 1. Muat file audio
            y, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            
            # 2. Ekstrak fitur MFCC (dengan n_mfcc=20)
            mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=N_MFCC)
            
            # 3. Ambil rata-rata MFCC di semua frame
            mfccs_rata_rata = np.mean(mfccs.T, axis=0)
            
            # 4. Simpan fitur dan label
            data_fitur.append(mfccs_rata_rata)
            data_label.append(label)
            
        except Exception as e:
            print(f"Error memproses file {file_path}: {e}")

print("\nEkstraksi fitur selesai.")

# --- Konversi ke DataFrame Pandas ---

# Buat DataFrame dari list fitur
df = pd.DataFrame(data_fitur)

# Beri nama kolom (mfcc_0, mfcc_1, ..., mfcc_19)
df = df.add_prefix('mfcc_')

# Tambahkan kolom label
df['label'] = data_label

# --- Simpan ke CSV ---
NAMA_FILE_CSV = "./dataset/data-hasil/fitur_audio_20mfcc.csv"
df.to_csv(NAMA_FILE_CSV, index=False)

print(f"Data fitur berhasil disimpan ke {NAMA_FILE_CSV}")
print("\nContoh 5 data pertama:")
print(df.head())
# Out:
# Memulai ekstraksi fitur MFCC (n_mfcc=20)...
# Processing buka: 100%|██████████| 100/100 [00:02<00:00, 46.00it/s]
# Processing tutup: 100%|██████████| 100/100 [00:01<00:00, 65.54it/s]
# Ekstraksi fitur selesai.
# Data fitur berhasil disimpan ke ./dataset/data-hasil/fitur_audio_20mfcc.csv
#
# Contoh 5 data pertama:
#        mfcc_0     mfcc_1     mfcc_2     mfcc_3     mfcc_4     mfcc_5  \
# 0 -391.825195  86.733055  21.756060  13.757183   9.030744  12.091555
# 1 -219.554581  95.143524  23.050543  11.273750  12.111441   7.253877
# 2 -231.499649  95.491196  21.786690  16.874832   9.731382  10.766232
# 3 -239.903519  93.402954  20.391285  14.796158   7.593359   8.971307
# 4 -239.522278  96.243011  13.798207  11.316676   9.502037   7.641552
#
#       mfcc_6    mfcc_7    mfcc_8    mfcc_9  ...   mfcc_11   mfcc_12   mfcc_13  \
# 0  12.048173  0.365709  1.737657  5.475190  ... -6.118983 -5.571948 -4.757148
# 1  12.820862 -2.045698 -0.279506  7.276806  ... -7.047171 -9.191520 -6.422854
# 2  14.763392  2.315336  0.482845  3.260504  ... -1.712604 -7.362328 -1.683394
# 3  12.700639 -0.081058  0.001442  4.289254  ... -2.979377 -8.099751 -2.410700
# 4  16.703917  0.591387 -1.314283  5.297466  ... -1.369699 -7.202394 -7.726523
#
#     mfcc_14   mfcc_15   mfcc_16   mfcc_17   mfcc_18   mfcc_19  label
# 0 -3.288465 -0.071312 -0.128426 -6.077927 -2.441211 -3.030537   buka
# 1 -3.832167 -0.068076 -3.157759 -4.752992 -6.085726 -4.260391   buka
# 2 -0.336681 -2.163007 -2.262357 -2.684976 -4.889982 -5.064355   buka
# 3 -0.211259 -2.033857 -2.743744 -4.011409 -4.766405 -5.796066   buka
# 4  0.504600 -3.000539 -4.273159 -3.424908 -4.315732 -7.084563   buka
#
# [5 rows x 21 columns]

# %%
# !pip install scikit-learn joblib

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# --- 1. Muat Data ---
NAMA_FILE_CSV = "./dataset/data-hasil/fitur_audio_20mfcc.csv"
df = pd.read_csv(NAMA_FILE_CSV)

print("Data berhasil dimuat:")
print(df.head())

# --- 2. Pra-pemrosesan Data ---

# Pisahkan fitur (X) dan label (y)
X = df.drop('label', axis=1) # Ambil semua kolom kecuali 'label'
y = df['label']

# Ubah label "buka" dan "tutup" menjadi angka (misal: 0 dan 1)
# Ini WAJIB karena model hanya mengerti angka
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Mari kita lihat kelasnya (0 itu apa, 1 itu apa)
print(f"\nKelas label: {encoder.classes_}")
# Ini akan mencetak sesuatu seperti: ['buka' 'tutup']
# Artinya: 'buka' = 0, 'tutup' = 1

# --- 3. Bagi Data (Train & Test Split) ---
# Kita akan gunakan 80% data untuk melatih model, 20% untuk menguji
# stratify=y_encoded: Memastikan proporsi 'buka' dan 'tutup' seimbang di data latih dan uji
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, 
                                                    test_size=0.2, 
                                                    random_state=42, 
                                                    stratify=y_encoded)

print(f"\nBentuk data latih (X_train): {X_train.shape}")
print(f"Bentuk data tes (X_test):   {X_test.shape}")

# --- 4. Buat dan Latih Model ---
print("\nMemulai pelatihan model SVC...")

# Kita gunakan SVC (Support Vector Classifier)
# kernel='linear' biasanya bekerja baik untuk data teks/audio
model = SVC(kernel='linear')

# Latih model menggunakan data latih
model.fit(X_train, y_train)

print("Pelatihan model selesai.")

# --- 5. Evaluasi Model ---
print("\n--- Hasil Evaluasi Model ---")
# Gunakan model yang sudah dilatih untuk menebak data tes
y_pred = model.predict(X_test)

# Hitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi Model: {accuracy * 100:.2f}%")

# Tampilkan laporan detail (precision, recall, f1-score)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=encoder.classes_))

# Tampilkan Confusion Matrix
# Ini menunjukkan berapa banyak 'buka' yang ditebak benar 'buka',
# berapa 'buka' yang salah tebak jadi 'tutup', dst.
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# --- 6. Simpan Model ---
# Ini adalah langkah KRUSIAL untuk implementasi Streamlit
NAMA_FILE_MODEL = './dataset/data-hasil/model_audio.pkl'
NAMA_FILE_ENCODER = './dataset/data-hasil/label_encoder.pkl'

joblib.dump(model, NAMA_FILE_MODEL)
joblib.dump(encoder, NAMA_FILE_ENCODER) # Kita juga simpan encoder-nya!

print(f"\nModel berhasil disimpan ke: {NAMA_FILE_MODEL}")
print(f"Encoder berhasil disimpan ke: {NAMA_FILE_ENCODER}")
# Out:
# Data berhasil dimuat:
#       mfcc_0     mfcc_1     mfcc_2     mfcc_3     mfcc_4     mfcc_5  \
# 0 -391.82520  86.733055  21.756060  13.757183   9.030744  12.091555
# 1 -219.55458  95.143524  23.050543  11.273750  12.111441   7.253877
# 2 -231.49965  95.491196  21.786690  16.874832   9.731382  10.766232
# 3 -239.90352  93.402954  20.391285  14.796158   7.593359   8.971307
# 4 -239.52228  96.243010  13.798207  11.316676   9.502037   7.641552
#
#       mfcc_6    mfcc_7    mfcc_8    mfcc_9  ...   mfcc_11   mfcc_12   mfcc_13  \
# 0  12.048173  0.365709  1.737657  5.475190  ... -6.118983 -5.571948 -4.757148
# 1  12.820862 -2.045698 -0.279506  7.276806  ... -7.047171 -9.191520 -6.422854
# 2  14.763392  2.315336  0.482845  3.260504  ... -1.712604 -7.362328 -1.683394
# 3  12.700639 -0.081058  0.001442  4.289254  ... -2.979377 -8.099751 -2.410700
# 4  16.703917  0.591387 -1.314283  5.297466  ... -1.369699 -7.202394 -7.726523
#
#     mfcc_14   mfcc_15   mfcc_16   mfcc_17   mfcc_18   mfcc_19  label
# 0 -3.288464 -0.071312 -0.128426 -6.077927 -2.441212 -3.030537   buka
# 1 -3.832167 -0.068076 -3.157759 -4.752992 -6.085726 -4.260391   buka
# 2 -0.336681 -2.163006 -2.262357 -2.684976 -4.889982 -5.064355   buka
# 3 -0.211259 -2.033857 -2.743744 -4.011409 -4.766405 -5.796066   buka
# 4  0.504600 -3.000539 -4.273159 -3.424908 -4.315732 -7.084563   buka
#
# [5 rows x 21 columns]
#
# Kelas label: ['buka' 'tutup']
#
# Bentuk data latih (X_train): (160, 20)
# Bentuk data tes (X_test):   (40, 20)
#
# Memulai pelatihan model SVC...
# Pelatihan model selesai.
#
# --- Hasil Evaluasi Model ---
# Akurasi Model: 97.50%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         buka       1.00      0.95      0.97        20
#        tutup       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
#
# Confusion Matrix:
# [[19  1]
#  [ 0 20]]
#
# Model berhasil disimpan ke: ./dataset/data-hasil/model_audio.pkl
# Encoder berhasil disimpan ke: ./dataset/data-hasil/label_encoder.pkl
